# %% [markdown]
# # モデルの説明
# 各種政策の変化に対して経済がどう反応するかをシミュレーションするために作ったモデル。
#
# ## 未解決事項
# - 振動が収まりにくい
# - GDP支出面と分配面が、TFMのどの変数の和に該当するのか、要調査
#
# ## 取引フロー表
# |                              | 労働者(経常)  | 労働者(資本)  |   投資家(経常)    |     投資家(資本)     |  企業(経常)   |     企業(資本)     |     民間金融機関     |     統合政府     | 合計 |
# | :--------------------------- | :-----------: | :-----------: | :---------------: | :------------------: | :-----------: | :----------------: | :------------------: | :--------------: | :--: |
# | 流動消費                     |    $-C_w$     |               |      $-C_i$       |                      |     $+C$      |                    |                      |                  | $0$  |
# | 消費財資産購入               |               |   $-C_{aw}$   |                   |      $-C_{ai}$       |    $+C_a$     |                    |                      |                  | $0$  |
# | 投資                         |               |               |                   |                      |     $+I$      |        $-I$        |                      |                  | $0$  |
# | 政府支出(公務員給与を除く)   |               |               |                   |                      |     $+G$      |                    |                      |       $-G$       | $0$  |
# | 賃金                         |     $+W$      |               |                   |                      |    $-W_f$     |                    |        $-W_b$        |      $-W_g$      | $0$  |
# | 所得税                       |   $-T_{iw}$   |               |     $-T_{ii}$     |                      |               |                    |                      |      $+T_i$      | $0$  |
# | 付加価値税                   |               |               |                   |                      |    $-T_v$     |                    |                      |      $+T_v$      | $0$  |
# | 法人税                       |               |               |                   |                      |   $-T_{ff}$   |                    |      $-T_{fb}$       |      $+T_f$      | $0$  |
# | 資産税                       |   $-T_{aw}$   |               |     $-T_{ai}$     |                      |   $-T_{af}$   |                    |                      |      $+T_a$      | $0$  |
# | 株式のキャピタルゲインへの税 |               |               |     $-T_{ci}$     |                      |               |                    |      $-T_{cb}$       |      $+T_c$      | $0$  |
# | 企業利潤                     |               |               |      $+P_i$       |                      |     $-P$      |       $+P_f$       |        $+P_b$        |                  | $0$  |
# | 金融機関から投資家への配当   |               |               |      $+TD_b$      |                      |               |                    |       $-TD_b$        |                  | $0$  |
# | 借入金利払い                 | $-r_LL_{w-1}$ |               |                   |                      | $-r_LL_{f-1}$ |                    |     $+r_LL_{-1}$     |                  | $0$  |
# | 国債金利払い                 |               |               | $+r_{GB}GB_{i-1}$ |                      |               |                    |  $+r_{GB}GB_{b-1}$   | $-r_{GB}GB_{-1}$ | $0$  |
# | 労働者貯蓄                   |    $-S_w$     |    $+S_w$     |                   |                      |               |                    |                      |                  | $0$  |
# | 投資家貯蓄                   |               |               |      $-S_i$       |        $+S_i$        |               |                    |                      |                  | $0$  |
# | [メモ:純貸出]                |               |  [ $NL_w$ ]   |                   |       [$NL_i$]       |               |      [$NL_f$]      |       [$NL_b$]       |     [$NL_g$]     | $0$  |
# | 預金の変化                   |               | $-\Delta M_w$ |                   |    $-\Delta M_i$     |               |   $-\Delta M_f$    |     $+\Delta M$      |                  | $0$  |
# | 借入金の変化                 |               | $+\Delta L_w$ |                   |                      |               |   $+\Delta L_f$    |     $-\Delta L$      |                  | $0$  |
# | 株式純発行                   |               |               |                   | $-p_{e-1}\Delta e_i$ |               | $+p_{e-1}\Delta e$ | $-p_{e-1}\Delta e_b$ |                  | $0$  |
# | 国債の変化                   |               |               |                   |    $-\Delta GB_i$    |               |                    |    $-\Delta GB_b$    |   $+\Delta GB$   | $0$  |
# | 現金の変化                   |               | $-\Delta H_w$ |                   |                      |               |                    |    $-\Delta H_b$     |   $+\Delta H$    | $0$  |
# | 合計                         |      $0$      |      $0$      |        $0$        |         $0$          |      $0$      |        $0$         |         $0$          |       $0$        |      |
#
#
# ## バランスシート表
# |                    | 労働者  |     資本家      |  企業   | 民間金融部門 | 統合政府 | 合計  |
# | :----------------- | :-----: | :-------------: | :-----: | :----------: | :------: | :---: |
# | 資本               | $+K_w$  |     $+K_i$      | $+K_f$  |              |          | $+K$  |
# | 預金               | $+M_w$  |     $+M_i$      | $+M_f$  |     $-M$     |          |  $0$  |
# | 借入金             | $-L_w$  |                 | $-L_f$  |     $+L$     |          |  $0$  |
# | 企業の株式および資本金         |         |     $+E_i$      |  $-E$   |    $+E_b$    |          |  $+NE$  |
# | 民間金融機関の株式 |         | $+D$ |         | $-D$ |          |  $0$  |
# | 国債               |         |     $+GB_i$     |         |   $+GB_b$    |  $-GB$   |  $0$  |
# | 現金               | $+H_w$  |                 |         |    $+H_b$    |   $-H$   |  $0$  |
# | 純資産             | $-NW_w$ |     $-NW_i$     | $-NW_f$ |   $-NW_b$    | $-NW_g$  | $-NW$ |
# | 合計               |   $0$   |       $0$       |   $0$   |     $0$      |   $0$    |  $0$  |
#
# ## 式一覧
# 上から順に計算する
#
# - $W_f=(1-\lambda_w)W_{f-1}+\lambda_w\delta(C_{-1}+C_{a-1}+I_{-1}+G_{-1}-T_{v-1}-T_{af-1}-r_LL_{f-1})$
# - $W_b=(1-\lambda_w)W_{b-1}+\lambda_w\delta(-T_{cb-1}+P_{b-1}-TD_{b-1}+r_LL_{-1}+r_{GB}GB_{b-1})$
# - $W_g=W_{g-1}(1+\gamma)$ (外生的に決める場合)
# - $W_g=(1-\lambda_g)(T_{i-1}+T_{a-1}+T_{c-1}+T_{v-1}+T_{f-1}-r_{GB}(GB_{-1}-\Delta GB_{-1}))(1+\gamma)$ (内生的に決める場合)
# - $W=W_f+W_b+W_g$
# - $T_{iw}=\epsilon_1 W$
# - $T_{ci}=\max\{0, \epsilon_7\Delta p_{e-1}(e_{i-1}-\Delta e_{i-1})+\epsilon_9(E_{i-1}+D_{-1})\}$
# - $T_{cb}=\max\{0, \epsilon_7\Delta p_{e-1}(e_{b-1}-\Delta e_{b-1})+\epsilon_9E_{b-1}\}$
# - $T_c=T_{ci}+T_{cb}$
# - $T_{aw}=\epsilon_5K_{w-1} + \epsilon_8(M_{w-1}-L_{i-1})$
# - $T_{ai}=\epsilon_5K_{i-1} + \epsilon_8(M_{i-1}+E_{i-1}+GB_{i-1})$
# - $T_{af}=\epsilon_6K_{f-1}$
# - $T_a=T_{aw}+T_{ai}+T_{af}$
# - $G=G_{g-1}(1+\gamma)$ (外生的に決める場合)
# - $G=\lambda_g(T_{i-1}+T_{a-1}+T_{c-1}+T_{v-1}+T_{f-1}-r_{GB}(GB_{-1}-\Delta GB_{-1}))(1+\gamma)$ (内生的に決める場合)
# - $C_w=\alpha_4\{\alpha_1(W-T_{iw}-T_{aw}-r_LL_{w-1})+\alpha_2(NW_{w-1}-K_{w-1})\}$
# - $C_i=\alpha_5\{\alpha_3(P_{i-1}+TD_{b-1}-T_{ii-1}-T_{ai-1}-T_{ci}+r_{GB}GB_{i-1})+\alpha_6(M_{i-1}+E_{i-1}+D_{-1}+GB_{i-1})\}$
# - $C=C_w+C_i$
# - $C_{aw}=(1-\alpha_4)\{\alpha_1(W-T_{iw}-T_{aw}-r_LL_{w-1})+\alpha_2(NW_{w-1}-K_{w-1})\}$
# - $C_{ai}=(1-\alpha_5)\{\alpha_3(P_{i-1}+TD_{b-1}-T_{ii-1}-T_{ai-1}-T_{ci}+r_{GB}GB_{i-1})+\alpha_6(M_{i-1}+E_{i-1}+D_{-1}+GB_{i-1})\}$
# - $C_a=C_{aw}+C_{ai}$
# - $I=\max[0, \min\{\beta_5(M_{f-1}-L_{f-1})+(\frac{C+C_a+G}{\beta_1 K_{f-1}}-u^T)K_{f-1}+\beta_2K_{f-1}, \beta_3(M_{f-1}-L_{f-1})\}]$
# - $T_v=\epsilon_2(C+C_a+G+I)$
# - $T_{ff}=\max\{0,\epsilon_3(C+C_a+G+I-W_f-T_v-T_{af}-r_LL_{f-1})\}$
# - $P=C+C_a+G+I-W_f-T_v-T_{ff}-T_{af}-r_LL_{f-1}$
# - $TD_f = \max\{0, \zeta_1(P-I)+\zeta_2(M_{f-1}-L_{f-1})\}$
# - $P_i=TD_f\frac{E_{i-1}}{E_{-1}}$
# - $P_b=TD_f\frac{E_{b-1}}{E_{-1}}$
# - $P_f=P-P_i-P_b$
# - $TD_b=\max\{0, \theta_1 (-M_{-1}+L_{-1}+E_{b-1}+GB_{b-1}+H_{b-1})+ \theta_2 NL_{b-1}\}$
# - $T_{ii}=\epsilon_4(P_i+TD_b+r_{GB}GB_{i-1})$
# - $T_i=T_{iw}+T_{ii}$
# - $T_{fb}=\max\{0, \epsilon_3(-W_b+P_b+r_LL_{-1}+r_{GB}GB_{b-1})\}$
# - $T_f=T_{ff}+T_{fb}$
# - $S_w=-C_w+W-T_{iw}-T_{aw}-r_LL_{w-1}$
# - $S_i=-C_i-T_{ii}-T_{ai}-T_{ci}+P_i+TD_b+r_{GB}GB_{i-1}$
# - $NL_w=-C_{aw}+S_w$
# - $NL_i=-C_{ai}+S_i$
# - $NL_f=P_f-I$
# - $NL_b=-W_b-T_{fb}-T_{cb}+P_b-TD_b+r_LL_{-1}+r_{GB}GB_{b-1}$
# - $NL_g=-G-W_g+T_i+T_v+T_f+T_a+T_c-r_{GB}GB_{-1}$
# - $L_w=\max\{\eta_1(W-T_{iw}-T_{aw}-r_LL_{w-1})\}$
# - $\Delta L_w=L_w-L_{w-1}$
# - $H_w=\eta_2C_w$
# - $\Delta H_w=H_w-H_{w-1}$
# - $\Delta M_w=NL_w+\Delta L_w-\Delta H_w$
# - $M_w=M_{w-1}+\Delta M_w$
# - $V_i^e=(1-\lambda_V)V_{i-1}^e+\lambda_VV_{i-1}\frac{V_{i-1}}{V_{i-1}-\Delta V_{i-1}}$
# - $V_b^e=(1-\lambda_V)V_{b-1}^e+\lambda_VV_{b-1}\frac{V_{b-1}}{V_{b-1}-\Delta V_{b-1}}$
# - $\Delta e=\frac{\eta_3(I-\beta_2K_{f-1})}{p_{e-1}}$
# - $e=e_{-1}+\Delta e$
# - $L_f=\eta_4(W_f+T_v+T_{ff}+T_{af})$
# - $\Delta L_f=L_f-L_{f-1}$
# - $\Delta L=\Delta L_w+\Delta L_f$
# - $L=L_{-1}+\Delta L$
# - $\Delta M_f=NL_f+\Delta L_f+p_{e-1}\Delta e$
# - $M_f=M_{f-1}+\Delta M_f$
#
# $$
# \begin{pmatrix}
#   M_i \\
#   E_i^e \\
#   D \\
#   GB_i^e
# \end{pmatrix}=
# \begin{pmatrix}
#   \lambda_{10} \\
#   \lambda_{20} \\
#   \lambda_{30} \\
#   \lambda_{40}
# \end{pmatrix}V_i^e+
# \begin{pmatrix}
#   \lambda_{11} & \lambda_{12} & \lambda_{13} & \lambda_{14}\\
#   \lambda_{21} & \lambda_{22} & \lambda_{23} & \lambda_{24}\\
#   \lambda_{31} & \lambda_{23} & \lambda_{33} & \lambda_{34}\\
#   \lambda_{41} & \lambda_{43} & \lambda_{43} & \lambda_{44}
# \end{pmatrix}
# \begin{pmatrix}
#   0 \\
#   \frac{TD_f}{E_{-1}} \\
#   \frac{TD_b}{D_{-1}}\\
#   r_{GB}
# \end{pmatrix}V_i^e
# $$
#
# $$
# \begin{pmatrix}
#   E_b^e \\
#   GB_b^e
# \end{pmatrix}=
# \begin{pmatrix}
#   \lambda_{50} \\
#   \lambda_{60}
# \end{pmatrix}V_b^e+
# \begin{pmatrix}
#   \lambda_{51} & \lambda_{52}\\
#   \lambda_{61} & \lambda_{62}
# \end{pmatrix}
# \begin{pmatrix}
#   \frac{TD_f}{E_{-1}} \\
#   r_{GB}
# \end{pmatrix}V_b^e
# $$
#
# - $p_e=\frac{E_i^e+E_b^e}{e}$
# - $\Delta p_e = p_e-p_{e-1}$
# - $\Delta M_i=M_i-M_{i-1}$
# - $\Delta M=\Delta M_w+\Delta M_i+\Delta M_f$
# - $M=M_{-1}+\Delta M$
# - $H_b=\eta_5M$
# - $\Delta H_b=H_b-H_{b-1}$
# - $\Delta H=\Delta H_w+\Delta H_b$
# - $H=H_{-1}+\Delta H$
# - $\Delta GB=-NL_g-\Delta H$
# - $GB=GB_{-1}+\Delta GB$
# - $GB_i=GB\frac{GB_i^e}{GB_i^e+GB_b^e}$
# - $GB_b=GB\frac{GB_b^e}{GB_i^e+GB_b^e}$
# - $\Delta GB_i=GB_i-GB_{i-1}$
# - $\Delta GB_b=GB_b-GB_{b-1}$
# - $\Delta e_i=\frac{1}{p_{e-1}}(NL_i-\Delta M_i-\Delta GB_i)$
# - $\Delta e_b=\Delta e-\Delta e_b$
# - $e_i=e_{i-1}+\Delta e_i$
# - $e_b=e_{b-1}+\Delta e_b$
# - $\Delta E_i=\Delta p_e e_i+p_{e-1}\Delta e_i$
# - $\Delta E_b=\Delta p_e e_b+p_{e-1}\Delta e_b$
# - $E_i=E_{i-1}+\Delta E_i$
# - $E_b=E_{b-1}+\Delta E_b$
# - $\Delta E=\Delta E_i+\Delta E_b$
# - $E=E_{-1}+\Delta E$
# - $V_i=M_i+E_i+D+GB_i$
# - $V_b=E_b+GB_b$
# - $\Delta D = D-D_{-1}$
# - $K_f=(1-\beta_2)K_{f-1}+I$
# - $K_w=(1-\beta_4)K_{w-1}+C_{aw}$
# - $K_i=(1-\beta_4)K_{i-1}+C_{ai}$
# - $K=K_w+K_i+K_f$
# - $NE=E_i+E_b-E$
# - $\Delta NE = NE - NE_{-1}$
# - $NW_w=K_w+M_w-L_w+H_w$
# - $NW_i=K_i+M_i+E_i+D+GB_i$
# - $NW_f=M_f-L_f-E+K_f$
# - $NW_b=-M+L+E_b-D+GB_b+H_b$
# - $NW_g=-GB-H$
# - $NW=K+NE$
#
# 隠れた恒等式の一部として
#
# - $NL_b+\Delta M-\Delta L-p_{e-1}\Delta e_b-\Delta GB_b-\Delta H_b=0$
# - $\Delta NE=\Delta E_i-\Delta E+\Delta E_b$
# - $M=M_w+M_i+M_f$
# - $L=L_w+L_f$
# - $E=E_i+E_b$
# - $GB=GB_i+GB_b$
# - $H=H_w+H_b$
# - $NW=NW_w+NW_i+NW_f+NW_b+NW_g$
#
# を会計的一貫性が満たされていることの確認に使う
#
# ## 外生変数とパラメータ
#
# - $(\alpha_1, \alpha_2, \alpha_3, \alpha_4, \alpha_5, \alpha_6)=(0.95, 0.05, 0.1, 0.8, 0.6, 0.01)$
# - $(\beta_1, \beta_2, \beta_3, \beta_4, \beta_5)=(1,0.05,1, 0.05, 0.05)$
# - $\gamma=0.02$ (外生的に決める場合)
# - $\gamma=0.1$ (内生的に決める場合)
# - $\delta=0.65$
# - $(\epsilon_1, \epsilon_2, \epsilon_3, \epsilon_4, \epsilon_5, \epsilon_6, \epsilon_7, \epsilon_8, \epsilon_9)=(0.2,0.1,0.2,0.4, 0.03, 0.03, 0.2, 0.01, 0.02)$
# - $\zeta_1, \zeta_2 =0.3, 0.1$
# - $(\eta_1,\eta_2,\eta_3,\eta_4,\eta_5)=(5,0.05,1,1,0.01)$
# - $(\theta_1, \theta_2)=(0.05, 0.3)$
# - $(\lambda_V, \lambda_w, \lambda_g)=(0.5, 0.5, 0.55)$
# - $(\lambda_{10}, \lambda_{20}, \lambda_{30}, \lambda_{40})=(0.3, 0.3, 0.1, 0.3)$
#
# $$
# \begin{pmatrix}
#   \lambda_{11} & \lambda_{12} & \lambda_{13} & \lambda_{14}\\
#   \lambda_{21} & \lambda_{22} & \lambda_{23} & \lambda_{24}\\
#   \lambda_{31} & \lambda_{23} & \lambda_{33} & \lambda_{34}\\
#   \lambda_{41} & \lambda_{43} & \lambda_{43} & \lambda_{44}
# \end{pmatrix}=
# \begin{pmatrix}
#   1 & -0.3 & -0.3 & -0.4\\
#   -0.3 & 1 & -0.4 & -0.3\\
#   -0.3 & -0.4 & 1 & -0.3\\
#   -0.4 & -0.3 & -0.3 & 1
# \end{pmatrix}
# $$
#
# - $(\lambda_{40}, \lambda_{50})=(0.5, 0.5)$
#
# $$
# \begin{pmatrix}
#   \lambda_{41} & \lambda_{42}\\
#   \lambda_{51} & \lambda_{52}
# \end{pmatrix}=
# \begin{pmatrix}
#   0.5 & -0.5\\
#   -0.5 & 0.5
# \end{pmatrix}
# $$
#
# - $(r_L,r_{GB})=(0.01, 0.02)$
# - $u^T=0.8$

# %% [markdown]
# # Juliaによる実装。

# %%
exogeneous = false
N=301

Cw, Ci, C, Caw, Cai, Ca, I, G = zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N)
W, Wf, Wb, Wg = zeros(N), zeros(N), zeros(N), zeros(N)
Tiw, Tii, Ti, Tv, Tff, Tfb, Tf, Taw, Tai, Taf, Ta, Tci, Tcb, Tc = zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N)
Pi, P, Pf, Pb, TDb, TDf, Sw, Si = zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N)
NLw, NLi, NLf, NLb, NLg = zeros(N), zeros(N), zeros(N), zeros(N), zeros(N)
ΔMw, ΔMi, ΔMf, ΔM = zeros(N), zeros(N), zeros(N), zeros(N)
ΔLw, ΔLf, ΔL = zeros(N), zeros(N), zeros(N)
Δei, Δeb, Δe = zeros(N), zeros(N), zeros(N)
ΔEi, ΔEb, ΔE, ΔNE = zeros(N), zeros(N), zeros(N), zeros(N)
D, ΔD = zeros(N), zeros(N)
ΔGBi, ΔGBb, ΔGB = zeros(N), zeros(N), zeros(N)
ΔHw, ΔHb, ΔH = zeros(N), zeros(N), zeros(N)
Kf, Kw, Ki, K = zeros(N), zeros(N), zeros(N), zeros(N)
Mw, Mi, Mf, M = zeros(N), zeros(N), zeros(N), zeros(N)
Lw, Lf, L = zeros(N), zeros(N), zeros(N)
ei, eb, e = zeros(N), zeros(N), zeros(N)
Ei, Eb, E, NE = zeros(N), zeros(N), zeros(N), zeros(N)
GBi, GBb, GB = zeros(N), zeros(N), zeros(N)
Hw, Hb, H = zeros(N), zeros(N), zeros(N)
NWw, NWi, NWf, NWb, NWg, NW = zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N)
Vi, Vb, Vie, Vbe, ΔVi, ΔVb = zeros(N), zeros(N), zeros(N), zeros(N), zeros(N), zeros(N)
Eie, GBie, Ebe, GBbe = zeros(N), zeros(N), zeros(N), zeros(N)
pe, Δpe = zeros(N), zeros(N)
rL, rGB, uT = 0.01, 0.02, 0.8
α1, α2, α3, α4, α5, α6 = 0.95, 0.05, 0.1, 0.8, 0.6, 0.01
β1, β2, β3, β4, β5 = 1, 0.05, 1, 0.05, 0.05
γ = 0.1
δ = 0.68
ϵ1, ϵ2, ϵ3, ϵ4, ϵ5, ϵ6, ϵ7, ϵ8, ϵ9 = 0.2, 0.1, 0.2, 0.4, 0.03, 0.03, 0.2, 0.01, 0.02
ζ1, ζ2 = 0.3, 0.1
η1, η2, η3, η4, η5 = 5, 0.05, 1, 1, 0.01
θ1, θ2 = 0.05, 0.3
λV, λw, λg = 0.5, 0.5, 0.55
λ10, λ20, λ30, λ40 = 0.3, 0.3, 0.1, 0.3
λ11, λ12, λ13, λ14 = 1, -0.3, -0.3, -0.4
λ21, λ22, λ23, λ24 = -0.3, 1, -0.4, -0.3
λ31, λ32, λ33, λ34 = -0.3, -0.4, 1, -0.3
λ41, λ42, λ43, λ44 = -0.4, -0.3, -0.3, 1
λ50, λ60 = 0.5, 0.5
λ51, λ52 = 0.5, -0.5
λ61, λ62 = -0.5, 0.5
G0, Wg0 = 1,0.9
G[1], Wg[1], W[1] = G0, Wg0, Wg0
pe[1] = 1
Kf[1], K[1] = 6, 6
Mw[1], Mi[1], Mf[1], M[1] = 1,1,1,3
ei[1], eb[1], e[1] = 2,2,4
Ei[1], Eb[1], E[1] = pe[1]*ei[1], pe[1]*eb[1], pe[1]*e[1]
D[1] = 1
GBi[1], GBb[1], GB[1] = 1,1,2
Hb[1], H[1] = η5*M[1],η5*M[1]
NWw[1] = Mw[1] - Lw[1] + Hw[1]
NWi[1] = Mi[1] + Ei[1] + D[1] + GBi[1]
NWf[1] = Mf[1] - Lf[1] - E[1] + Kf[1]
NWb[1] = -M[1] + L[1] + Eb[1] - D[1] + GBb[1] + Hb[1]
NWg[1] = -GB[1] - H[1]
NW[1] = K[1] + NE[1]
Vi[1], Vb[1], Vie[1], Vbe[1] = Mi[1]+Ei[1]+GBi[1], Eb[1]+GBb[1], Mi[1]+Ei[1]+GBi[1], Eb[1]+GBb[1]

function run(time_range::UnitRange)
    for t=time_range
        Wf[t] = (1-λw)*Wf[t-1] + λw*δ*(C[t-1]+Ca[t-1]+I[t-1]+G[t-1]-Tv[t-1]-Taf[t-1]-rL*Lf[t-1])
        Wb[t] = (1-λw)*Wb[t-1] + λw*δ*(-Tcb[t-1]+Pb[t-1]-TDb[t-1]+rL*L[t-1]+rGB*GBb[t-1])
        if exogeneous
            Wg[t] = Wg[t-1]*(1+γ)
        else
            Wg[t] = (1-λg)*(Ti[t-1]+Ta[t-1]+Tc[t-1]+Tv[t-1]+Tf[t-1]-rGB*(GB[t-1]-ΔGB[t-1]))*(1+γ)
        end
        W[t] = Wf[t] + Wb[t] + Wg[t]
        Tiw[t] = ϵ1*W[t]
        Tci[t] = max(0, ϵ7*Δpe[t-1]*(ei[t-1]-Δei[t-1])+ϵ9*(Ei[t-1]+D[t-1]))
        Tcb[t] = max(0, ϵ7*Δpe[t-1]*(eb[t-1]-Δeb[t-1])+ϵ9*Eb[t-1])
        Tc[t] = Tci[t] + Tcb[t]
        Taw[t] = ϵ5*Kw[t-1] + ϵ8*(Mw[t-1]-Lw[t-1])
        Tai[t] = ϵ5*Ki[t-1] + ϵ8*(Mi[t-1]+Ei[t-1]+GBi[t-1])
        Taf[t] = ϵ6*Kf[t-1]
        Ta[t] = Taw[t] + Tai[t] + Taf[t]
        if exogeneous
            G[t] = G[t-1]*(1+γ)
        else
            G[t] = λg*(Ti[t-1]+Ta[t-1]+Tc[t-1]+Tv[t-1]+Tf[t-1]-rGB*(GB[t-1]-ΔGB[t-1]))*(1+γ)
        end
        Cw[t] = α4*(α1*(W[t]-Tiw[t]-Taw[t]-rL*Lw[t-1]) + α2*(NWw[t-1]-Kw[t-1]))
        Ci[t] = α5*(α3*(Pi[t-1]+TDb[t-1]-Tii[t-1]-Tai[t-1]-Tci[t]+rGB*GBi[t-1])+α6*(Mi[t-1]+Ei[t-1]+D[t-1]+GBi[t-1]))
        C[t] = Cw[t] + Ci[t]
        Caw[t] = (1 - α4)*(α1*(W[t]-Tiw[t]-Taw[t]-rL*Lw[t-1]) + α2*(NWw[t-1]-Kw[t-1]))
        Cai[t] = (1 - α5)*(α3*(Pi[t-1]+TDb[t-1]-Tii[t-1]-Tai[t-1]-Tci[t]+rGB*GBi[t-1])+α6*(Mi[t-1]+Ei[t-1]+D[t-1]+GBi[t-1]))
        Ca[t] = Caw[t] + Cai[t]
        I[t] = max(0, min(β5*(Mf[t-1]-Lf[t-1])+((C[t]+Ca[t]+G[t])/(β1*Kf[t-1]) - uT)*Kf[t-1] + β2*Kf[t-1], β3*(Mf[t-1]-Lf[t-1])))
        Tv[t] = ϵ2*(C[t]+Ca[t]+G[t]+I[t])
        Tff[t] = max(0, ϵ3*(C[t]+Ca[t]+G[t]+I[t]-Wf[t]-Tv[t]-Taf[t]-rL*Lf[t-1]))
        P[t] = C[t]+Ca[t]+G[t]+I[t]-Wf[t]-Tv[t]-Tff[t]-Taf[t]-rL*Lf[t-1]
        TDf[t] = max(0, ζ1*(P[t]-I[t])+ζ2*(Mf[t-1]-Lf[t-1]))
        Pi[t] = TDf[t]*Ei[t-1]/(Ei[t-1]+Eb[t-1])
        Pb[t] = TDf[t]*Eb[t-1]/(Ei[t-1]+Eb[t-1])
        Pf[t] = P[t]-Pi[t]-Pb[t]
        TDb[t] = max(0, θ1*(-M[t-1]+L[t-1]+Eb[t-1]+GBb[t-1]+Hb[t-1]) + θ2*NLb[t-1])
        Tii[t] = ϵ4*(Pi[t]+TDb[t]+rGB*GBi[t-1])
        Ti[t] = Tiw[t] + Tii[t]
        Tfb[t] = max(0, ϵ3*(-Wb[t]-Tcb[t]+Pb[t]+rL*L[t-1]+rGB*GBb[t-1]))
        Tf[t] = Tff[t] + Tfb[t]
        Sw[t] = -Cw[t]+W[t]-Tiw[t]-Taw[t]-rL*Lw[t-1]
        Si[t] = -Ci[t]-Tii[t]-Tai[t]-Tci[t]+Pi[t]+TDb[t]+rGB*GBi[t-1]
        NLw[t] = -Caw[t]+Sw[t]
        NLi[t] = -Cai[t]+Si[t]
        NLf[t] = Pf[t] - I[t]
        NLb[t] = -Wb[t] - Tfb[t] - Tcb[t] + Pb[t] - TDb[t] + rL*L[t-1] + rGB*GBb[t-1]
        NLg[t] = -G[t] - Wg[t] + Ti[t] + Tv[t] + Tf[t] + Ta[t] + Tc[t] - rGB*GB[t-1]
        Lw[t] = max(0, η1*(W[t] - Tiw[t] - Taw[t] - rL*Lw[t-1]))
        ΔLw[t] = Lw[t] - Lw[t-1]
        Hw[t] = η2*Cw[t]
        ΔHw[t] = Hw[t] - Hw[t-1]
        ΔMw[t] = NLw[t] + ΔLw[t] - ΔHw[t]
        Mw[t] = Mw[t-1] + ΔMw[t]
        Vie[t] = (1-λV)*Vie[t-1] + λV*Vi[t-1]^2/(Vi[t-1]-ΔVi[t-1])
        Vbe[t] = (1-λV)*Vbe[t-1] + λV*Vb[t-1]^2/(Vb[t-1]-ΔVb[t-1])
        Δe[t] = η3*(I[t]-β2*Kf[t-1])/pe[t-1]
        e[t] = e[t-1] + Δe[t]
        Lf[t] = η4*(Wf[t]+Tv[t]+Tff[t]+Taf[t])
        ΔLf[t] = Lf[t] - Lf[t-1]
        ΔL[t] = ΔLw[t] + ΔLf[t]
        L[t] = L[t-1] + ΔL[t]
        ΔMf[t] = NLf[t] + ΔLf[t] + pe[t-1]*Δe[t]
        Mf[t] = Mf[t-1] + ΔMf[t]
        Mi[t] = (λ10 + λ12*TDf[t]/(Ei[t-1]+Eb[t-1]) + λ13*TDb[t]/D[t-1] + λ14*rGB)*Vie[t]
        Eie[t] = (λ20 + λ22*TDf[t]/(Ei[t-1]+Eb[t-1]) + λ23*TDb[t]/D[t-1] + λ24*rGB)*Vie[t]
        D[t] = (λ30 + λ32*TDf[t]/(Ei[t-1]+Eb[t-1]) + λ33*TDb[t]/D[t-1] + λ34*rGB)*Vie[t]
        GBie[t] = (λ40 + λ42*TDf[t]/(Ei[t-1]+Eb[t-1]) + λ43*TDb[t]/D[t-1] + λ44*rGB)*Vie[t]
        Ebe[t] = (λ50 + λ51*TDf[t]/(Ei[t-1]+Eb[t-1]) + λ52*rGB)*Vbe[t]
        GBbe[t] = (λ60 + λ61*TDf[t]/(Ei[t-1]+Eb[t-1]) + λ62*rGB)*Vbe[t]
        pe[t] = (Eie[t] + Ebe[t])/e[t]
        Δpe[t] = pe[t] - pe[t-1]
        ΔMi[t] = Mi[t] - Mi[t-1]
        ΔM[t] = ΔMw[t] + ΔMi[t] + ΔMf[t]
        M[t] = M[t-1] + ΔM[t]
        Hb[t] = η5*M[t]
        ΔHb[t] = Hb[t] - Hb[t-1]
        ΔH[t] = ΔHw[t] + ΔHb[t]
        H[t] = H[t-1] + ΔH[t]
        ΔGB[t] = -NLg[t] - ΔH[t]
        GB[t] = GB[t-1] + ΔGB[t]
        GBi[t] = GB[t]*GBie[t]/(GBie[t]+GBbe[t])
        GBb[t] = GB[t]*GBbe[t]/(GBie[t]+GBbe[t])
        ΔGBi[t] = GBi[t] - GBi[t-1]
        ΔGBb[t] = GBb[t] - GBb[t-1]
        Δei[t] = max(-ei[t-1], (NLi[t] - ΔMi[t] - ΔGBi[t])/pe[t-1])
        Δeb[t] = Δe[t] - Δei[t]
        ei[t] = ei[t-1] + Δei[t]
        eb[t] = eb[t-1] + Δeb[t]
        ΔEi[t] = Δpe[t]*ei[t] + pe[t-1]*Δei[t]
        ΔEb[t] = Δpe[t]*eb[t] + pe[t-1]*Δeb[t]
        Ei[t] = Ei[t-1] + ΔEi[t]
        Eb[t] = Eb[t-1] + ΔEb[t]
        ΔE[t] = pe[t-1]*Δe[t]
        E[t] = E[t-1] + ΔE[t]
        Vi[t] = Mi[t] + Ei[t] + D[t] + GBi[t]
        Vb[t] = Eb[t] + GBb[t]
        ΔD[t] = D[t] - D[t-1]
        Kf[t] = (1-β2)*Kf[t-1] + I[t]
        Kw[t] = (1-β4)*Kw[t-1] + Caw[t]
        Ki[t] = (1-β4)*Ki[t-1] + Cai[t]
        K[t] = Kf[t] + Kw[t] + Ki[t]
        NE[t] = Ei[t] + Eb[t] - E[t]
        ΔNE[t] = NE[t] - NE[t-1]
        NWw[t] = Kw[t] + Mw[t] - Lw[t] +Hw[t]
        NWi[t] = Ki[t] + Mi[t] + Ei[t] + D[t] + GBi[t]
        NWf[t] = Mf[t] - Lf[t] - E[t] + Kf[t]
        NWb[t] = -M[t] + L[t] + Eb[t] - D[t] + GBb[t] + Hb[t]
        NWg[t] = -GB[t] - H[t]
        NW[t] = K[t] + NE[t]
    end
end
run(2:N)

# %% [markdown]
# ## 会計的一貫性の確認
#
# - $NL_b+\Delta M-\Delta L-p_{e-1}\Delta e_b-\Delta GB_b-\Delta H_b=0$
# - $\Delta NE=\Delta E_i-\Delta E+\Delta E_b$
# - $M=M_w+M_i+M_f$
# - $L=L_w+L_f$
# - $GB=GB_i+GB_b$
# - $H=H_w+H_b$
# - $NW=NW_w+NW_i+NW_f+NW_b+NW_g$
#
# の誤差をプロットする

# %%
using StatsPlots
plot(2:N, NLb[2:end]+ΔM[2:end]-ΔL[2:end]-pe[1:end-1].*Δeb[2:end]-ΔGBb[2:end]-ΔHb[2:end], label=nothing)
plot!(1:N, ΔNE+ΔE-ΔEi-ΔEb, label=nothing)
plot!(1:N, M-Mw-Mi-Mf, label=nothing)
plot!(1:N, L-Lw-Lf, label=nothing)
plot!(1:N, GB-GBi-GBb, label=nothing)
plot!(1:N, H-Hw-Hb, label=nothing)
plot!(1:N, NW-NWw-NWi-NWf-NWb-NWg, label=nothing)

# %% [markdown]
# いずれも計算機側の都合で誤差が出るが、のちにプロットする変数の値を見ればわかる通りオーダーが$10^{10}$以上違う。モデルの会計的一貫性は保たれていると言って良い

# %% [markdown]
# ## 長期安定状態の確認
# いくつかの変数（名目値）を持ってきて、一定の割合で推移するようになるかどうかを確認する
#
# $t<10$の範囲では、$G<0$になる場合があるので、方対数グラフのために$t=10$からプロットする

# %%
plot(10:N, G[10:end], label="G", xlabel="t", yscale=:log10)
plot!(10:N, C[10:end], label="C", yscale=:log10)
plot!(10:N, W[10:end], label="W", yscale=:log10)
plot!(10:N, M[10:end], label="M", yscale=:log10)
plot!(10:N, L[10:end], label="L", yscale=:log10)
plot!(10:N, GB[10:end], label="GB", yscale=:log10)
plot!(10:N, Ei[10:end], label="Ei", yscale=:log10)

# %% [markdown]
# $t=100$あたりから方対数プロットの傾きがどの変数も同じ程度になっている。すなわち長期安定状態を確認

# %% [markdown]
# # パラメータの変化への反応を実験

# %% [markdown]
# ## 特定のパラメータの変更に対して特定の変数がどのように影響を受けるか、差分をシミュレーションしてプロット

# %%
run(2:N) # ベースラインシナリオを計算
plot(-10:40, I[end-50:end], label="baseline", title="I")

#   ここでパラメータを変える
#rGB = 0.03         #   国債の利回りの増加
#ϵ5, ϵ8 = 0.05, 0.02#   家計の資産税増税
#ϵ6 = 0.01          #   企業の資本への課税の増税
#ϵ1, ϵ4 = 0.3, 0.6  #   所得税増税
#ϵ2 = 0.05          #   付加価値税増税
#ϵ3 = 0.1           #   法人税増税
#γ = 0.00           #   政府支出増加率減少
δ = 0.65            #   賃金への分配割合の増減

run(N-40:N) # パラメータの変化に対する短期・中期・長期的影響をシミュレーションする
plot!(-10:40, I[end-50:end], label="control")

# %% [markdown]
# ## 変数の推移をプロット

# %% [markdown]
# ### GDPの支出面

# %%
plot(-10:40, C[end-50:end], label="C"  )
plot!(-10:40, Ca[end-50:end], label="Ca"  )
plot!(-10:40, I[end-50:end], label="I"  )
plot!(-10:40, G[end-50:end], label="G"  )
plot!(-10:40, Wg[end-50:end], label="Wg"  )

# %% [markdown]
# ### 消費

# %%
plot(-10:40, C[end-50:end], label="C"  )
plot!(-10:40, Cw[end-50:end], label="Cw"  )
plot!(-10:40, Ci[end-50:end], label="Ci"  )
plot!(-10:40, Ca[end-50:end], label="Ca"  )
plot!(-10:40, Caw[end-50:end], label="Caw"  )
plot!(-10:40, Cai[end-50:end], label="Cai"  )

# %% [markdown]
# ### 所得税

# %%
plot(-10:40, Ti[end-50:end], label="Ti"  )
plot!(-10:40, Tiw[end-50:end], label="Tiw"  )
plot!(-10:40, Tii[end-50:end], label="Tii"  )

# %% [markdown]
# ### 資産への税

# %%
plot(-10:40, Ta[end-50:end], label="Ta"  )
plot!(-10:40, Taw[end-50:end], label="Taw"  )
plot!(-10:40, Tai[end-50:end], label="Tai"  )
plot!(-10:40, Taf[end-50:end], label="Taf"  )

# %% [markdown]
# ### 法人税

# %%
plot(-10:40, Tf[end-50:end], label="Tf"  )
plot!(-10:40, Tfb[end-50:end], label="Tfb"  )
plot!(-10:40, Tff[end-50:end], label="Tff"  )

# %% [markdown]
# ### 株式のキャピタルゲインへの税

# %%
plot(-10:40, Tc[end-50:end], label="Tc"  )
plot!(-10:40, Tcb[end-50:end], label="Tcb"  )
plot!(-10:40, Tci[end-50:end], label="Tci"  )

# %% [markdown]
# ### 税

# %%
plot(-10:40, Ti[end-50:end], label="Ti"  )
plot!(-10:40, Tv[end-50:end], label="Tv"  )
plot!(-10:40, Tf[end-50:end], label="Tf"  )
plot!(-10:40, Ta[end-50:end], label="Ta"  )
plot!(-10:40, Tc[end-50:end], label="Tc"  )

# %% [markdown]
# ### 賃金

# %%
plot(-10:40, W[end-50:end], label="W"  )
plot!(-10:40, Wf[end-50:end], label="Wf"  )
plot!(-10:40, Wb[end-50:end], label="Wb"  )
plot!(-10:40, Wg[end-50:end], label="Wg"  )

# %% [markdown]
# ### 配当

# %%
plot(-10:40, TDb[end-50:end], label="TDb"  )
plot!(-10:40, TDf[end-50:end], label="TDf"  )

# %% [markdown]
# ### 企業利潤

# %%
plot(-10:40, P[end-50:end], label="P"  )
plot!(-10:40, Pb[end-50:end], label="Pb"  )
plot!(-10:40, Pi[end-50:end], label="Pi"  )
plot!(-10:40, Pf[end-50:end], label="Pf"  )

# %% [markdown]
# ### 預金

# %%
plot(-10:40, Mw[end-50:end], label="Mw"  )
plot!(-10:40, Mi[end-50:end], label="Mi"  )
plot!(-10:40, Mf[end-50:end], label="Mf"  )
plot!(-10:40, M[end-50:end], label="M"  )

# %% [markdown]
# ### 預金変動

# %%
plot(-10:40, ΔMw[end-50:end], label="ΔMw")
plot!(-10:40, ΔMi[end-50:end], label="ΔMi")
plot!(-10:40, ΔMf[end-50:end], label="ΔMf")
plot!(-10:40, ΔM[end-50:end], label="ΔM")

# %% [markdown]
# ### 株式発行部数

# %%
plot(-10:40, e[end-50:end], label="e"  )
plot!(-10:40, ei[end-50:end], label="ei"  )
plot!(-10:40, eb[end-50:end], label="eb"  )

# %% [markdown]
# ### 株式発行部数の変動

# %%
plot(-10:40, Δe[end-50:end], label="Δe")
plot!(-10:40, Δei[end-50:end], label="Δei")
plot!(-10:40, Δeb[end-50:end], label="Δeb")

# %% [markdown]
# ### 株価

# %%
plot(-10:40, pe[end-50:end], label="pe"  )

# %% [markdown]
# ### 資本

# %%
plot(-10:40, K[end-50:end], label="K"  )
plot!(-10:40, Kf[end-50:end], label="Kf"  )
plot!(-10:40, Ki[end-50:end], label="Ki"  )
plot!(-10:40, Kw[end-50:end], label="Kw"  )

# %% [markdown]
# ### 借入金

# %%
plot(-10:40, L[end-50:end], label="L"  )
plot!(-10:40, Lw[end-50:end], label="Lw"  )
plot!(-10:40, Lf[end-50:end], label="Lf"  )

# %% [markdown]
# ### 借入金の変動

# %%
plot(-10:40, ΔL[end-50:end], label="ΔL")
plot!(-10:40, ΔLw[end-50:end], label="ΔLw")
plot!(-10:40, ΔLf[end-50:end], label="ΔLf")

# %% [markdown]
# ### 資本金・株式保有額

# %%
plot(-10:40, E[end-50:end], label="E"  )
plot!(-10:40, Ei[end-50:end], label="Ei"  )
plot!(-10:40, Eb[end-50:end], label="Eb"  )
plot!(-10:40, D[end-50:end], label="D"  )
plot!(-10:40, NE[end-50:end], label="NE"  )

# %% [markdown]
# ### 現金

# %%
plot(-10:40, H[end-50:end], label="H"  )
plot!(-10:40, Hw[end-50:end], label="Hw"  )
plot!(-10:40, Hb[end-50:end], label="Hb"  )

# %% [markdown]
# ### 現金の変動

# %%
plot(-10:40, ΔH[end-50:end], label="ΔH")
plot!(-10:40, ΔHw[end-50:end], label="ΔHw")
plot!(-10:40, ΔHb[end-50:end], label="ΔHb")

# %% [markdown]
# ### 国債

# %%
plot(-10:40, GB[end-50:end], label="GB"  )
plot!(-10:40, GBi[end-50:end], label="GBi"  )
plot!(-10:40, GBb[end-50:end], label="GBb"  )

# %% [markdown]
# ### 国債の変動

# %%
plot(-10:40, ΔGB[end-50:end], label="ΔGB")
plot!(-10:40, ΔGBi[end-50:end], label="ΔGBi")
plot!(-10:40, ΔGBb[end-50:end], label="ΔGBb")

# %% [markdown]
# ### 純資産

# %%
plot(-10:40, NWw[end-50:end], label="NWw")
plot!(-10:40, NWi[end-50:end], label="NWi")
plot!(-10:40, NWf[end-50:end], label="NWf")
plot!(-10:40, NWb[end-50:end], label="NWb")
plot!(-10:40, NWg[end-50:end], label="NWg")

# %% [markdown]
# ### 純貸出（収支）

# %%
plot(-10:40, NLw[end-50:end], label="NLw")
plot!(-10:40, NLi[end-50:end], label="NLi")
plot!(-10:40, NLf[end-50:end], label="NLf")
plot!(-10:40, NLb[end-50:end], label="NLb")
plot!(-10:40, NLg[end-50:end], label="NLg")

# %% [markdown]
# ### 債務残高対GDP比

# %% [markdown]
# GDPの計算方法を要確認

# %%
plot(-10:40, (H+GB)[end-50:end]./((C+Ca+G+I+Wg)[end-50:end]+rL*L[end-51:end-1]), label="(H+GB)/GDP")

# %% [markdown]
# ### GDP成長率と企業の資本収益率
# GDPは支出面の変数の合計で計算、民間の資本収益率は$\frac{P+TD_b+r_LL+r_{GB}GB}{K+M+L+E_i+E_b+D+GB+H}$で計算

# %% [markdown]
# GDPと民間の資本収益率の計算方法を要確認

# %%
g = (C[2:end] + Ca[2:end] + I[2:end] + G[2:end] + Wg[2:end])./(C[1:end-1] + Ca[1:end-1] + I[1:end-1] + G[1:end-1] + Wg[1:end-1]) .- 1
r = (P+TDb+rL*L+rGB*GB)./(K+M+L+Ei+Eb+D+GB+H)
plot(-10:40, r[end-50:end], label="r")
plot!(-10:40, g[end-50:end], label="g")

# %% [markdown]
# ### 民間資産対GDP比および民間純資産対GDP比

# %% [markdown]
# 民間資産対GDP比がおよそ５程度になるらしい。ピケティによると。

# %%
plot(-10:40, (K+M+L+Ei+Eb+D+GB+H)[end-50:end]./((C+Ca+G+I+Wg)[end-50:end]+rL*L[end-51:end-1]), label="private asset per GDP")
plot!(-10:40, (NWw+NWi+NWf+NWb)[end-50:end]./((C+Ca+G+I+Wg)[end-50:end]+rL*L[end-51:end-1]), label="private net asset per GDP")

# %% [markdown]
# ### GDP支出面と分配面

# %% [markdown]
# このモデルでは在庫がなく、生産したものがそのまま売れるので、支出面と分配面が厳密に一致するはず。GDPの支出面と分配面を理解する必要がある。モデルで用いた変数では支出面と分配面を適切に記述できない可能性もある

# %%
plot((C+Ca+G+I+Wg)[end-50:end])
plot!((W+Tv+Tf+P+TDb)[end-50:end]+β2*Kf[end-51:end-1])
